# %%
# set up
import pandas as pd
import twython
from twython import Twython
APP_KEY = 'z5W0ogHsEpx12EPZAgCTLXOWd'
APP_SECRET = 'eLVZazK5i2we9s0jlIflBSSeNaZwi1Yfns3UXlOb0Qvue1q5CQ'
twitter = Twython(APP_KEY, APP_SECRET, oauth_version=2)
ACCESS_TOKEN = twitter.obtain_access_token()
twitter = Twython(APP_KEY, access_token=ACCESS_TOKEN)

# %%
# code from:
# https://stackoverflow.com/questions/19320197/twython-search-api-with-next-results#comment45223247_21644346

# i will try to combine my code with the data frame and this stack overflow code.
tweets = pd.DataFrame()
MAX_ATTEMPTS = 450
#COUNT_OF_TWEETS_TO_BE_FETCHED = 10

for i in range(0,MAX_ATTEMPTS):


    #if(COUNT_OF_TWEETS_TO_BE_FETCHED < len(tweets)):
        #break # we got 500 tweets... !!

    #----------------------------------------------------------------#
    # STEP 1: Query Twitter
    # STEP 2: Save the returned tweets
    # STEP 3: Get the next max_id
    #----------------------------------------------------------------#

    # STEP 1: Query Twitter
    if(0 == i):
        #print(i)
        

        results = twitter.search(q="#bitcoin or #btc",lang='en', result_type='mixed',count='100',since_id='1323410828654071008')
        
        
    else:
        #print(i)
        # After the first call we should have max_id from result of previous call. Pass it in query.
        results = twitter.search(q="#bitcoin or #btc",lang='en', result_type='mixed',count='100', 
                                 include_entities='true',max_id=next_max_id)
        

    # STEP 2: Save the returned tweets
    for result in results['statuses']:
        #print(i)
        df=pd.DataFrame()
        df=pd.DataFrame.from_dict(results['statuses'])
        tweets=tweets.append(df)



    # STEP 3: Get the next max_id
    
        # Parse the data returned to get max_id to be passed in consequent call.
      
    next_results_url_params = results['search_metadata']['next_results']
    next_max_id = next_results_url_params.split('max_id=')[1].split('&')[0]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-24-5afcd6728ab1> in <module>
#      47         # Parse the data returned to get max_id to be passed in consequent call.
#      48
# ---> 49     next_results_url_params = results['search_metadata']['next_results']
#      50     next_max_id = next_results_url_params.split('max_id=')[1].split('&')[0]
#      51
#
# KeyError: 'next_results'

# %%
tweets.to_csv('raw_tweets.csv')

# %%
d=pd.read_csv('raw_tweets.csv')
# Out:
# /opt/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3071: DtypeWarning: Columns (17) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,

# %%
d.head()
# Out:
#    Unnamed: 0                      created_at                   id  \
# 0           0  Fri Nov 06 17:45:21 +0000 2020  1324769858093985795
# 1           1  Fri Nov 06 17:42:25 +0000 2020  1324769119418392577
# 2           2  Fri Nov 06 17:24:56 +0000 2020  1324764717848563712
# 3           3  Fri Nov 06 17:20:39 +0000 2020  1324763638884958211
# 4           4  Fri Nov 06 17:06:22 +0000 2020  1324760046031589381
#
#                 id_str                                               text  \
# 0  1324769858093985795  What is worser? Getting shot in the arm or get...
# 1  1324769119418392577  Can someone help me check if this #bitcoin bot...
# 2  1324764717848563712  My earning from Vitae 344$ \nIt was less than ...
# 3  1324763638884958211  #bitcoin #btc #Binance\nBuy or Sell Bitcoin an...
# 4  1324760046031589381  RT @CoinMarketCap: Looks like most people are ...
#
#    truncated                                           entities  \
# ...

# %%
d.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 239805 entries, 0 to 239804
# Data columns (total 31 columns):
#  #   Column                     Non-Null Count   Dtype
# ---  ------                     --------------   -----
#  0   Unnamed: 0                 239805 non-null  int64
#  1   created_at                 239805 non-null  object
#  2   id                         239805 non-null  int64
#  3   id_str                     239805 non-null  int64
#  4   text                       239805 non-null  object
#  5   truncated                  239805 non-null  bool
#  6   entities                   239805 non-null  object
#  7   metadata                   239805 non-null  object
#  8   source                     233808 non-null  object
#  9   in_reply_to_status_id      7699 non-null    float64
#  10  in_reply_to_status_id_str  7699 non-null    float64
#  11  in_reply_to_user_id        7899 non-null    float64
#  12  in_reply_to_user_id_str    7899 non-null    float64
# ...
